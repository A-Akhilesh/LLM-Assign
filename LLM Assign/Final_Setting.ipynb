# %%
# %pip install langchain_community
# %pip install langchain_openai
# %pip install sentence_transformers
# %pip install langchain_experimental
# %pip install langchain_huggingface
# %pip install pandas
# %pip install langchain_google_genai
# %pip install streamlit
# Out:
# Requirement already satisfied: langchain_community in c:\work\llm submission\llm trial 2\.env\lib\site-packages (0.2.6)
# Requirement already satisfied: PyYAML>=5.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.6 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (0.2.6)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (0.2.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (0.1.82)
# Requirement already satisfied: numpy<2,>=1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_community) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain<0.3.0,>=0.2.6->langchain_community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain<0.3.0,>=0.2.6->langchain_community) (2.7.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain_community) (2.18.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain_openai in c:\work\llm submission\llm trial 2\.env\lib\site-packages (0.1.10)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_openai) (0.2.10)
# Requirement already satisfied: openai<2.0.0,>=1.26.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_openai) (1.35.5)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_openai) (0.1.82)
# Requirement already satisfied: packaging<25,>=23.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_openai) (2.7.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_openai) (8.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.26.0->langchain_openai) (3.7)
# Requirement already satisfied: certifi in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain_openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_openai) (3.10.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain_openai) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.2.2)
# Requirement already satisfied: colorama in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.26.0->langchain_openai) (0.4.6)
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sentence_transformers in c:\work\llm submission\llm trial 2\.env\lib\site-packages (3.0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (4.41.2)
# Requirement already satisfied: tqdm in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (2.3.1)
# Requirement already satisfied: numpy in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (1.5.0)
# Requirement already satisfied: scipy in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (0.23.4)
# Requirement already satisfied: Pillow in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: filelock in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: requests in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.12.1)
# Requirement already satisfied: networkx in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence_transformers) (2021.4.0)
# Requirement already satisfied: colorama in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence_transformers) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence_transformers) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: langchain_experimental in c:\work\llm submission\llm trial 2\.env\lib\site-packages (0.0.62)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_experimental) (0.2.6)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_experimental) (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.6 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.2.6)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.1.82)
# Requirement already satisfied: numpy<2,>=1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (8.4.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_experimental) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_experimental) (2.7.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain<0.3.0,>=0.2.6->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.2.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.10.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.0.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain_huggingface in c:\work\llm submission\llm trial 2\.env\lib\site-packages (0.0.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_huggingface) (0.23.4)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_huggingface) (0.2.10)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_huggingface) (3.0.1)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_huggingface) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_huggingface) (4.41.2)
# Requirement already satisfied: filelock in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.1.82)
# Requirement already satisfied: pydantic<3,>=1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.7.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (8.4.2)
# Requirement already satisfied: torch>=1.11.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.3.1)
# Requirement already satisfied: numpy in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.5.0)
# Requirement already satisfied: scipy in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.14.0)
# Requirement already satisfied: Pillow in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (10.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain_huggingface) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain_huggingface) (3.10.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.6.2)
# Requirement already satisfied: sympy in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.12.1)
# Requirement already satisfied: networkx in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.3)
# Requirement already satisfied: jinja2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2021.4.0)
# Requirement already satisfied: colorama in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain_huggingface) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\work\llm submission\llm trial 2\.env\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Collecting langchain_google_genai
#   Using cached langchain_google_genai-1.0.7-py3-none-any.whl (36 kB)
# Collecting google-generativeai<0.8.0,>=0.7.0 (from langchain_google_genai)
#   Using cached google_generativeai-0.7.1-py3-none-any.whl (163 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.2.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain_google_genai) (0.2.10)
# Collecting google-ai-generativelanguage==0.6.6 (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai)
#   Using cached google_ai_generativelanguage-0.6.6-py3-none-any.whl (718 kB)
# Collecting google-api-core (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai)
#   Using cached google_api_core-2.19.1-py3-none-any.whl (139 kB)
# Collecting google-api-python-client (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai)
#   Using cached google_api_python_client-2.134.0-py2.py3-none-any.whl (11.9 MB)
# Collecting google-auth>=2.15.0 (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai)
#   Using cached google_auth-2.30.0-py2.py3-none-any.whl (193 kB)
# Requirement already satisfied: protobuf in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (4.25.3)
# Requirement already satisfied: pydantic in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (2.7.4)
# Requirement already satisfied: tqdm in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (1.24.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.9->langchain_google_genai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.9->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.9->langchain_google_genai) (0.1.82)
# Requirement already satisfied: packaging<25,>=23.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.9->langchain_google_genai) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langchain-core<0.3,>=0.2.9->langchain_google_genai) (8.4.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.9->langchain_google_genai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain_google_genai) (3.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain_google_genai) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pydantic->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (2.18.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (1.63.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (0.22.0)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai)
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (4.1.1)
# Requirement already satisfied: colorama in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from tqdm->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (1.64.1)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai)
#   Using cached grpcio_status-1.64.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain_google_genai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain_google_genai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain_google_genai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain_google_genai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain_google_genai) (2024.6.2)
# INFO: pip is looking at multiple versions of grpcio-status to determine which version is compatible with other requirements. This could take a while.
#   Using cached grpcio_status-1.64.0-py3-none-any.whl (14 kB)
#   Using cached grpcio_status-1.63.0-py3-none-any.whl (14 kB)
#   Using cached grpcio_status-1.62.2-py3-none-any.whl (14 kB)
# Installing collected packages: grpcio-status, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai, langchain_google_genai
# Successfully installed google-ai-generativelanguage-0.6.6 google-api-core-2.19.1 google-api-python-client-2.134.0 google-auth-2.30.0 google-auth-httplib2-0.2.0 google-generativeai-0.7.1 grpcio-status-1.62.2 langchain_google_genai-1.0.7
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting streamlitNote: you may need to restart the kernel to use updated packages.
#
#   Using cached streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Using cached altair-5.3.0-py3-none-any.whl (857 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (2.32.3)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Requirement already satisfied: toolz in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: referencing>=0.28.4 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\work\llm submission\llm trial 2\.env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: rich, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed altair-5.3.0 gitpython-3.1.43 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 pydeck-0.9.1 rich-13.7.1 streamlit-1.36.0
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from PyPDF2 import PdfReader
from dotted_dict import DottedDict
import numpy as np
from langchain_community.vectorstores import Chroma
from langchain_openai import AzureOpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer
import faiss
from langchain_core.documents import Document
recursive_text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# %%
def read_pdf(file_path):
    content = ""
    with open(file_path, 'rb') as file:
        reader = PdfReader(file)
        for page in range(len(reader.pages)):
            content += reader.pages[page].extract_text()
    return content

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
def sem_process_pdfs(pdf_directory):
    documents = []

    for filename in os.listdir(pdf_directory):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(pdf_directory, filename)
            content = read_pdf(pdf_path)

            # Split text into chunks
            split_chunks = recursive_text_splitter.split_text(content)
            text_splitter = SemanticChunker(embeddings)
            split_chunks = text_splitter.create_documents([content])

            # Create Document objects with metadata
            for chunk in split_chunks:
                chunk.metadata['pdf_name'] = filename
                print(type(chunk))
                documents.append(chunk)
    return documents
# Out:
# c:\Work\LLM Submission\LLM Trial 2\.env\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
documents = sem_process_pdfs("data")
# Out:
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>
# <class 'langchain_core.documents.base.Document'>

# %%
import pandas as pd
data = []
for doc in documents:
    row = {
        "content": doc.page_content,
        "pdf_name": doc.metadata["pdf_name"]
    }
    data.append(row)
 
# Create a DataFrame and save to CSV
df = pd.DataFrame(data)
csv_path = "processed_documents.csv"
df.to_csv(csv_path, index=False)
